# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x **2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x, y, 'b') # 'r' is the color red
plt.xlabel('X Axis ')
plt.ylabel('Y Axis ')
plt.title('Shubham Nikam')
#plt.grid()
plt.grid(axis = 'x')
plt.show()

# %% [markdown]
# # Multi Plots on Same canvas

# %%
plt.subplot(1,2,1)
plt.plot(x,y, 'g<-')
plt.subplot(1,2,2)
plt.grid(color = 'blue', linestyle = '--', linewidth = 0.5)
plt.plot(y,x, 'c*-');

# %%
plt.scatter(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 11 artists>

# %%
shubham = np.random.normal(120,20,350)
#np.random.normal(loc, scale and size)
plt.hist(x)
plt.show()

# %%
y =np.array([20,25,25,20])

plt.pie(y)

mylabels = ["India", "Russia", "Australia", "Portugal"]

plt.pie(y, labels=mylabels)
plt.show()

# %% [markdown]
# Object Oriented Methods

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
fig = plt.figure()

axes = fig.add_axes([0.2,0.2,0.4,0.4]) #left bottom width height

axes.plot(x, y, 'm--')
axes.set_xlabel(' X label')
axes.set_ylabel(' Y label')
axes.set_title('Shubham')
# Out:
# Text(0.5, 1.0, 'Shubham')

# %% [markdown]
# # Inset Graph

# %%
# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.6, 0.4, 0.2]) # inset axes

# Larger Figure Axes 1
axes1.plot(x, y, 'b--')
axes1.set_xlabel('X_label_axes1')
axes1.set_ylabel('Y_label_axes1')
axes1.set_title('Axes 1 Title')

# Insert Figure Axes 2
axes2.plot(y, x, 'r|-')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title');

# %% [markdown]
# # subplots

# %%
fig, axes = plt.subplots()

axes.plot(x,y, 'c')
axes.set_label('x axis')
axes.set_ylabel('y axis')
axes.set_title('Shubham Nikam')
# Out:
# Text(0.5, 1.0, 'Shubham Nikam')

# %%
#empty canvas of 1 by 2 subplots

fig, axes = plt.subplots(nrows=1, ncols=4)

# %%
axes
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
for ax in axes:
  ax.plot(x,y, 'g')
  ax.set_xlabel('x_axis')
  ax.set_ylabel('y axis')
  ax.set_title('32')

fig

# %%
fig, axes = plt.subplots(nrows =1, ncols =4)

for ax in axes:
  ax.plot(x,y, 'g')
  ax.set_xlabel('x_axis')
  ax.set_ylabel('y axis')
  ax.set_title('sn32')

fig.tight_layout()
