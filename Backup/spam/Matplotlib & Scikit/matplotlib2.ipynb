# %% [markdown]
# # **Part2**

# %% [markdown]
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the figsize and dpi keyword arguments.
#  - figsize is a tuple of the width and height of the figue in inches
#  - dpi is the dots-per-inch(pixel per inch)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(0,5,11)
y = x ** 2

# %%
fig = plt.figure(figsize=(4,4), dpi=50)

# %% [markdown]
# The same arguments can also be passed to layout managers, such as the subplots function:

# %%
fig, axes = plt.subplots(figsize=(4,5), dpi=100)

axes.plot(x, y,'yellow')
axes.set_xlabel('My x axis')
axes.set_ylabel('My y axis')
axes.set_title('Shubham');

# %% [markdown]
# # **Saving Figures**
# Matplotlib can generate high-quality outputp in a number formats, including PNG,JPG,EPS,SVG,PGF and PDF.
#
# To save a figure to a file can use the savefig method in the Figure class:

# %%
import os
import matplotlib.pyplot as plt

script_dir = os.path.dirname('graph')
results_dir = os.path.join(script_dir, 'Resulsts/')
sample_file_name = "sample"

if not os.path.isdir(results_dir):
  os.makedirs(results_dir)

# %% [markdown]
# Here we can also optionally specify the DPI and choose between different output formatsL

# %%
fig.savefig("graph22.png", dpi=200)

# %% [markdown]
# # **Legends**
# You can use the label="label text" keyword argument when plots or other objects are added to the figure and then using the leg method without arguments to add the legend to the figure

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2, label="x**3")
ax.plot(x, x**3, label="x**4")
ax.legend()

# %% [markdown]
# Notice: how are legend overlaps some of the actual plot
# The legend functuin takes an optional keyword argument loc that can ve used specify where in the figure tge legend is to be drawn. The allowed valuse of loc are numerical codes for the various places the legend can be drawn.

# %%
# Lots of options,,,

ax.legend(loc=1) #upper right corner
ax.legend(loc=2) #upper left corner
ax.legend(loc=3) #lower left corner
ax.legend(loc=4) #lower left corner

#Many more options are available
# Most common to share
ax.legend(loc=0)
fig

# %% [markdown]
# # **Setting color, linewidths, linetypes**

# %% [markdown]
# Colors with MatLablikr syntaxx
# With matplotlib we can define the colors of lines and other graphical elements in a number of ways. for examole, 'b-' means a birderline with dots

# %%
# MATLAB style line color and style
fig,ax = plt.subplots()
ax.plot(x, x**2, 'b.-') #blue line with dots
ax.plot(x, x**3, 'g--') #green dashed Line

# %% [markdown]
# Colors with the color= parameter
#
# We can also define colors by their names or RGB hex codes and optiinally provide an alpha value using the color and alpha keyword arguements. Alpha indicates opacity.

# %%
fig, ax = plt.subplots()

ax.plot(x, x+1, color="blue", alpha = 0.2) #half-transparent
ax.plot(x, x+2, color="#8B008B") #Rgb Hex codes
ax.plot(x, x+3, color="#FF8C00") #Rgb Hex codes

# %% [markdown]
# # **Line and Marker styles**
#
# To change the line width, we can use the linewidth or lw keyword argument. The line style can be selected using the linesty ls keyword arguments

# %%
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="yellow", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="red", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="blue", lw=1, ls='-', marker='s', markersize=15,
        markerfacecolor="red", markeredgewidth=3, markeredgecolor="blue")

# %% [markdown]
# Control over axis Appearance
# In this we look at controlling axis sizing properties in a matplotlib figure.

# %% [markdown]
# # **Plot Range**
#
# We can configure the ranges of the axes using the set_ylim and set_xlim methods in the axis object, or axis('tight') for automatically getiing "tightly fitted" axes ranges:

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x**2, x,x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x,x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0,60])
axes[2].set_xlim([2,5])
axes[2].set_title("custom axes range");

# %% [markdown]
# # **Boxplot**
# It is used to identify outliers in datasets.

# %%
data = [np.random.normal(2, std, 100) for std in range(1,4)]

#rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);

# %%
data
# Out:
# [array([3.96320508, 3.65483183, 5.04098423, 4.59290103, 1.88022543,
#         3.37531169, 1.00722109, 2.60595744, 0.96260526, 0.01450712,
#         1.84325983, 1.85226841, 4.24576253, 2.69198367, 2.66473548,
#         0.40282623, 2.23274471, 0.27754922, 3.65819522, 1.51504648,
#         3.20388447, 2.00863211, 2.78717094, 1.63003005, 2.02415811,
#         0.17460069, 1.32229952, 4.23183502, 3.40614791, 0.61758709,
#         3.91738176, 2.94873405, 1.9363175 , 2.29531459, 4.05012908,
#         0.59533204, 0.13685484, 2.3198688 , 3.50197871, 2.44662934,
#         1.45914596, 2.43418649, 1.17001545, 2.3755925 , 1.15053304,
#         0.67518434, 4.19892303, 0.42450081, 3.70037186, 2.06890291,
#         3.69720215, 0.93840406, 1.98626553, 2.19151764, 2.87949013,
#         1.71836492, 0.27931119, 1.70713459, 2.7332144 , 1.95811156,
#         1.45526884, 1.33509896, 2.19972797, 0.79426595, 1.41910967,
#         4.26698994, 2.4814437 , 3.68177888, 3.87479448, 2.59902677,
# ...

# %% [markdown]
# # **End of Lesson 5.2**
